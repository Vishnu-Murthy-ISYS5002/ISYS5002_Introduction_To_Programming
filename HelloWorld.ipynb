# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishnu-Murthy-ISYS5002/ISYS5002_Introduction_To_Programming/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
print (1+2)
# Out:
# Hello World
# 3
